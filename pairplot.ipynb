# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import unicodecsv as csv
# df = pd.read_csv('C:/Users/Gajraj/Documents/Brand-AE.csv', encoding = 'ascii')
name = "QA-Brand"

excel_workbook = 'D:/Work/SnapChat/ROW/Vidtech_Monthly_Deck/6thStreet/6thStreet-Pairplot.xlsx'
df = pd.read_excel(excel_workbook, sheet_name = name)

# df.head()

p1 = sns.pairplot(df, x_vars='CTR', y_vars='%Contribution in Revenue', palette='Paired', 
#                   markers=["o","s", "D","v","<",">","8","d","P","p","h","H"],size=6, height=1, aspect=1,#12
#                   markers=["o","s", "D","v","<",">","8","d","P","p","h"],size=6, height=1, aspect=1,#11
#                   markers=["o","s","D","v","<",">","8","d","P","p"],size=6, height=1, aspect=1, #10
                  markers=["o","s", "D","v","<",">","8","d","P"],size=6, height=1, aspect=1,#9
#                   markers=["o","s","D","v","<",">","8","d"],size=6, height=1, aspect=1,#8
#                   markers=["o","s","D","v","<",">","8"],size=6, height=1, aspect=1,#7
#                   markers=["o","s","D","v","<",">"],size=6, height=1, aspect=1,#6
#                   markers=["o","s","D","v","<"],size=6, height=1, aspect=1,#5
#                   markers=["o","s","D","v"],size=6, height=1, aspect=1,#4
#                   markers=["o","s","D"],size=6, height=1, aspect=1,#3
                  plot_kws=dict(s=400,  linewidth=2) , kind='scatter', hue=name)
# plt.xlim(0.014,0.0325)
# plt.ylim(0.025,0.115)
plt.title(name)
plt.savefig("C:/Users/Gajraj Singh/Downloads/" + name + ".png")
