# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
Data= pd.read_csv('E:\imsproschool\Regression.csv')

# %%
Data.head()
# Out:
#     Age    Job Type Marital Status Education Metro City  \
# 0  28.0  Unemployed             No  Graduate         No
# 1  57.0     Retired            Yes  Graduate        Yes
# 2  27.0     Student            Yes  Graduate        Yes
# 3  23.0  Unemployed            Yes  Secondry        Yes
# 4  23.0    Employed            Yes  Graduate        Yes
#
#    Signed in since(Days)  Purchase made
# 0                     32       261.4689
# 1                     31       273.9025
# 2                     31       275.8921
# 3                     34       295.1524
# 4                     42       325.0809

# %%
Data.shape
# Out:
# (325, 7)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 7 columns):
# Age                      312 non-null float64
# Job Type                 325 non-null object
# Marital Status           325 non-null object
# Education                325 non-null object
# Metro City               325 non-null object
# Signed in since(Days)    325 non-null int64
# Purchase made            325 non-null float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 17.9+ KB

# %%
Data['Age'].isnull().sum()
# Out:
# 13

# %%
#We have 13 null values in Age

# %%
Data.describe(include='all')
# Out:
#                Age  Job Type Marital Status Education Metro City  \
# count   312.000000       325            325       325        325
# unique         NaN         4              2         3          2
# top            NaN  Employed            Yes  Graduate        Yes
# freq           NaN       236            192       237        256
# mean     38.349359       NaN            NaN       NaN        NaN
# std       8.267808       NaN            NaN       NaN        NaN
# min      23.000000       NaN            NaN       NaN        NaN
# 25%      32.000000       NaN            NaN       NaN        NaN
# 50%      38.000000       NaN            NaN       NaN        NaN
# 75%      44.000000       NaN            NaN       NaN        NaN
# max      65.000000       NaN            NaN       NaN        NaN
#
#         Signed in since(Days)  Purchase made
# count              325.000000      325.00000
# unique                    NaN            NaN
# top                       NaN            NaN
# ...

# %%
Data.isnull().sum()
# Out:
# Age                      13
# Job Type                  0
# Marital Status            0
# Education                 0
# Metro City                0
# Signed in since(Days)     0
# Purchase made             0
# dtype: int64

# %%
Data.head()
# Out:
#     Age    Job Type Marital Status Education Metro City  \
# 0  28.0  Unemployed             No  Graduate         No
# 1  57.0     Retired            Yes  Graduate        Yes
# 2  27.0     Student            Yes  Graduate        Yes
# 3  23.0  Unemployed            Yes  Secondry        Yes
# 4  23.0    Employed            Yes  Graduate        Yes
#
#    Signed in since(Days)  Purchase made
# 0                     32       261.4689
# 1                     31       273.9025
# 2                     31       275.8921
# 3                     34       295.1524
# 4                     42       325.0809

# %%
#Univariate analysis

# %%
sns.boxplot(data=Data['Age'])

# %%
sns.boxplot(data=Data['Signed in since(Days)'])

# %%
sns.boxplot(data=Data['Purchase made'])

# %%
#Bivariate

sns.pairplot(Data, x_vars=['Age','Signed in since(Days)'], y_vars='Purchase made',
             size=9, aspect=0.7, kind='scatter',hue='Education')

# %%
sns.pairplot(Data, x_vars=['Age','Signed in since(Days)'], y_vars='Purchase made',
             size=9, aspect=0.7, kind='scatter',hue='Metro City')

# %%
sns.pairplot(Data, x_vars=['Age','Signed in since(Days)'], y_vars='Purchase made',
             size=9, aspect=0.7, kind='scatter',hue='Job Type')

# %%
Data.head()
# Out:
#     Age    Job Type Marital Status Education Metro City  \
# 0  28.0  Unemployed             No  Graduate         No
# 1  57.0     Retired            Yes  Graduate        Yes
# 2  27.0     Student            Yes  Graduate        Yes
# 3  23.0  Unemployed            Yes  Secondry        Yes
# 4  23.0    Employed            Yes  Graduate        Yes
#
#    Signed in since(Days)  Purchase made
# 0                     32       261.4689
# 1                     31       273.9025
# 2                     31       275.8921
# 3                     34       295.1524
# 4                     42       325.0809

# %%
sns.boxplot(x=Data['Marital Status'],y=Data["Purchase made"])

# %%
sns.boxplot(x=Data['Job Type'],y=Data["Purchase made"])

# %%
#Education vs Purchase made wrt Metro
plt.rcParams['figure.figsize'] = (18, 15)
plt.subplot(2, 2, 1)
sns.violinplot(x = Data['Education'], y = Data['Purchase made'], hue = Data['Metro City'], palette = 'rainbow')
plt.title('Education vs Purchase made wrt Metro', fontsize = 30)

# Job Type vs Purchase made wrt Metro
plt.subplot(2, 2, 2)
sns.violinplot(x = Data['Job Type'], y = Data['Purchase made'], hue = Data['Metro City'], palette = 'gnuplot')
plt.title('Job Type vs Purchase made wrt Metro', fontsize = 30)

# Marital Status vs Purchase made wrt Metro
plt.subplot(2, 2, 3)
sns.violinplot(x = Data['Marital Status'], y = Data['Purchase made'], hue = Data['Metro City'], palette = 'Greens')
plt.title('Marital Status vs Purchase made wrt Metro', fontsize = 30)
# Out:
# Text(0.5,1,'Marital Status vs Purchase made wrt Metro')

# %%
Data['Age'] = Data.Age.fillna( Data.Age.mean() )

# %%
Data.isnull().sum()
# Out:
# Age                      0
# Job Type                 0
# Marital Status           0
# Education                0
# Metro City               0
# Signed in since(Days)    0
# Purchase made            0
# dtype: int64

# %%
#Correlation
plt.figure(figsize = (6,6))
sns.heatmap(Data.corr(),annot = True)
sns.set(font_scale=1)

# %%
Data.head()
# Out:
#     Age    Job Type Marital Status Education Metro City  \
# 0  28.0  Unemployed             No  Graduate         No
# 1  57.0     Retired            Yes  Graduate        Yes
# 2  27.0     Student            Yes  Graduate        Yes
# 3  23.0  Unemployed            Yes  Secondry        Yes
# 4  23.0    Employed            Yes  Graduate        Yes
#
#    Signed in since(Days)  Purchase made
# 0                     32       261.4689
# 1                     31       273.9025
# 2                     31       275.8921
# 3                     34       295.1524
# 4                     42       325.0809

# %%
#Separate num and categ

Data_num= Data[['Age','Signed in since(Days)']]

Data_cat= Data[['Job Type','Marital Status','Education','Metro City']]

# %%
Data_dummies = pd.get_dummies(Data_cat)

# %%
Data_combined= pd.concat([Data_num,Data_dummies], axis=1)

# %%
Data_combined.head()
# Out:
#     Age  Signed in since(Days)  Job Type_Employed  Job Type_Retired  \
# 0  28.0                     32                  0                 0
# 1  57.0                     31                  0                 1
# 2  27.0                     31                  0                 0
# 3  23.0                     34                  0                 0
# 4  23.0                     42                  1                 0
#
#    Job Type_Student  Job Type_Unemployed  Marital Status_No  \
# 0                 0                    1                  1
# 1                 0                    0                  0
# 2                 1                    0                  0
# 3                 0                    1                  0
# 4                 0                    0                  0
#
#    Marital Status_Yes  Education_Graduate  Education_Primary  \
# 0                   0                   1                  0
# 1                   1                   1                  0
# ...

# %%
#Splitting
X= Data_combined
y= Data['Purchase made']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8 , random_state=100)
# Out:
# C:\Users\MyPc\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(lm.intercept_)
# Out:
# -9432.579480780027

# %%
coeff_df = pd.DataFrame(lm.coef_,X_test.columns,columns=['Coefficient'])
coeff_df
# Out:
#                        Coefficient
# Age                      35.182120
# Signed in since(Days)   185.378850
# Job Type_Employed       -23.566079
# Job Type_Retired       -251.868673
# Job Type_Student        695.328904
# Job Type_Unemployed    -419.894152
# Marital Status_No       288.990332
# Marital Status_Yes     -288.990332
# Education_Graduate      957.939115
# Education_Primary      -838.366494
# Education_Secondry     -119.572620
# Metro City_No          -675.704648
# Metro City_Yes          675.704648

# %%
y_pred = lm.predict(X_test)

# %%
import statsmodels.api as sm
X_train_sm = X_train
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
# create a fitted model in one line
lm_1 = sm.OLS(y_train,X_train_sm).fit()

# print the coefficients
lm_1.params
# Out:
# const                   -3651.321089
# Age                        35.182120
# Signed in since(Days)     185.378850
# Job Type_Employed        -936.396352
# Job Type_Retired        -1164.698945
# Job Type_Student         -217.501368
# Job Type_Unemployed     -1332.724424
# Marital Status_No       -1536.670212
# Marital Status_Yes      -2114.650877
# Education_Graduate       -259.167915
# Education_Primary       -2055.473524
# Education_Secondry      -1336.679650
# Metro City_No           -2501.365193
# Metro City_Yes          -1149.955896
# dtype: float64

# %%
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          Purchase made   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     118.0
# Date:                Sat, 10 Aug 2019   Prob (F-statistic):           9.62e-85
# Time:                        20:29:18   Log-Likelihood:                -2296.7
# No. Observations:                 260   AIC:                             4613.
# Df Residuals:                     250   BIC:                             4649.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -3651.3211    331.240    -11.023      0.000   -4303.698   -2998.944
# ...
