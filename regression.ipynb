# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('E:\pythonEx\Regression.csv')

# %%
df.describe()
# Out:
#               Age  Signed in since(Days)  Purchase made
# count  312.000000             325.000000      325.00000
# mean    38.349359              79.476923     7525.62652
# std      8.267808              17.273676     3770.51836
# min     23.000000              31.000000      261.46890
# 25%     32.000000              73.000000     5138.02240
# 50%     38.000000              84.000000     7624.78240
# 75%     44.000000              92.000000     9854.53290
# max     65.000000             108.000000    17355.42760

# %%
# df['Age'] = df['Age'].fillna(df['Age'].mean())
# df
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C174479630>,
# ...
#       dtype=object)

# %%
# Out:
#       Age    Job Type Marital Status Education Metro City  \
# 0    28.0  Unemployed             No  Graduate         No
# 1    57.0     Retired            Yes  Graduate        Yes
# 2    27.0     Student            Yes  Graduate        Yes
# 3    23.0  Unemployed            Yes  Secondry        Yes
# 4    23.0    Employed            Yes  Graduate        Yes
# 5    58.0     Retired            Yes  Graduate        Yes
# 6    26.0    Employed             No  Graduate         No
# 7     NaN  Unemployed             No  Graduate         No
# 8    56.0     Retired             No  Graduate         No
# 9    23.0  Unemployed            Yes  Secondry        Yes
# 10   57.0     Retired            Yes  Secondry        Yes
# 11   29.0  Unemployed            Yes  Secondry        Yes
# 12   59.0     Retired             No  Graduate         No
# 13    NaN  Unemployed            Yes  Graduate        Yes
# 14   61.0     Retired            Yes  Graduate        Yes
# ...
