# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/gajrajsingh/Downloads/orders - orders.csv')

# %%
df.head()
# Out:
#    Sno  Order_Number                     Items  \
# 0    1     300536847  SA357ELAHV8WSGAMZ-248327
# 1    2     300136847  CA680FAACYYHSGAMZ-147599
# 2    3     300336847   PA258HLAAKPQSGAMZ-26864
# 3    6     300649847   BR660HLAAKPOSGAMZ-26862
# 4    7     300649847  AL221HBAE22BSGAMZ-199814
#
#                                         Product_Name  Unit_Price  Revenue  \
# 0    SanDisk CZ43 Ultra Fit USB 3.0 Flash Drive 64GB       49.00    49.00
# 1  Casio Analog Digital Tough Solar Men's White R...       52.78    42.78
# 2  Panasonic Hair Styler With Two Attachments EH-...       18.00    18.00
# 3           Braun Satin Hair 3 Dryer HD 330 (EXPORT)       44.00    37.16
# 4  Algenist Firming & Lifting Eye Gel 15ml/0.5oz ...       84.67    71.51
#
#    Discount  Customer_Shipping_Fee Payment_Method Device_Type
# 0      0.00                    0.5    Cybersource     desktop
# 1     10.00                    2.5    Cybersource  androidApp
# ...

# %%
import mysql.connector
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:pari%402014@localhost:3306/temp', echo = True)
df.to_sql(name = 'Orders', con = engine, if_exists = 'append', index = False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# ...

# %%
SQLALCHEMY_DATABASE_URI= 'mysql+mysqldb://root:pari@2014@localhost:3306/temp'
df.to_sql(name = 'Orders', con = engine, if_exists = 'append', index = False)

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = msql.connect(host='localhost', user='root',  
                        password='Pari@2014')#give ur username, password
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("CREATE DATABASE LazadaOrders")
        print("Database is created")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Error while connecting to MySQL Authentication plugin 'caching_sha2_password' is not supported

# %%
pip install mysql-connector-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 576.9 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 962.3/962.3 KB 134.8 kB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cryptography
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
