# %%
import json
import pandas as pd
import pandas_gbq as gbq
from google.oauth2 import service_account
from json import dumps

dt = {
  "type": "service_account",
  "project_id": "vid-ai",
  "private_key_id": "ce8f487a7fab8710fb95f6a7d0e24d82951e89c6",
  "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
  "client_email": "vid-ai-reporting@vid-ai.iam.gserviceaccount.com",
  "client_id": "108777497607443562446",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/vid-ai-reporting%40vid-ai.iam.gserviceaccount.com"
}

with open("bquery-key.json", "w") as f:
    f.write(dumps(dt))

key_path = "bquery-key.json"

credential = service_account.Credentials.from_service_account_file(key_path)

account_query = '''SELECT distinct Actionkey, countryShort, eventItemJson FROM `vid-ai.first_party_data.goldenscent` WHERE DATE(eventDateTime) between "2019-11-09" AND "2019-11-13" AND Actionkey = "purchase"'''
account_data = pd.read_gbq(account_query, project_id=dt['project_id'], index_col=None, col_order=None, reauth=False, auth_local_webserver=False, dialect=None, location=None, configuration=None, credentials=credential, use_bqstorage_api=None, private_key=None, verbose=None)
account_data.head()
# Out:
#   Actionkey countryShort                                      eventItemJson
# 0  purchase           SA  {"cart.fees_COD":"25  ر.س","cart.fees_shipping...
# 1  purchase           SA  {"cart.total":"311  ر.س","order.id":"201056214...
# 2  purchase           SA  {"cart.fees_shipping":"مجانا","cart.subtotal":...
# 3  purchase           SA  {"product.0.name":"ريد توباكو","user.age":"29"...
# 4  purchase           SA  {"product.0.qty_in_cart":"1","cart.fees_shippi...

# %%
account_data['eventItemJson'][4]
# Out:
# '{"product.0.qty_in_cart":"1","cart.fees_shipping":"19\xa0 ر.س","product.0.id":"1817","user.email":"j3-2009@hotmail.com","product.isAR":"0","user.id":"729753","user.name":"الجوهرة ..","product.0.qty":"993","order_id":"201056479","cart.subtotal":"111\xa0 ر.س","user.age":"25","user.gender":"0","product.0.brand":"كالفن كلاين","product.0.name":"اتيرنتي مومنت - 100 مل","product.0.price":"111"}'

# %%
def get_value(x, col) :
    if x is None : return None
    else : return json.loads(x).get(col)

account_data['Brand'] = account_data['eventItemJson'].apply(lambda x: get_value(x, 'product.0.brand'))
account_data['Name'] = account_data['eventItemJson'].apply(lambda x: get_value(x, 'product.0.name'))
account_data['Price'] = account_data['eventItemJson'].apply(lambda x: get_value(x, 'product.0.price'))
account_data['ProductId'] = account_data['eventItemJson'].apply(lambda x: get_value(x, 'product.0.id'))

# %%
account_data.head()
# Out:
#   Actionkey countryShort                                      eventItemJson  \
# 0  purchase           SA  {"cart.fees_COD":"25  ر.س","cart.fees_shipping...
# 1  purchase           SA  {"cart.total":"311  ر.س","order.id":"201056214...
# 2  purchase           SA  {"cart.fees_shipping":"مجانا","cart.subtotal":...
# 3  purchase           SA  {"product.0.name":"ريد توباكو","user.age":"29"...
# 4  purchase           SA  {"product.0.qty_in_cart":"1","cart.fees_shippi...
#
#          Brand                    Name Price ProductId
# 0         None                    None  None      None
# 1         None                    None  None      None
# 2       جيرلان     مون جيرلان - 100 مل   374      5220
# 3      مانسيرا              ريد توباكو   441      6172
# 4  كالفن كلاين  اتيرنتي مومنت - 100 مل   111      1817

# %%
df = account_data.drop(['eventItemJson'], axis=1)

# %%
df.to_excel('E:/Work/SnapChat/ROW/Product/GS_Top5.xlsx')

# %%
import numpy as np
df['Brand'].replace('', np.nan, inplace=True)
df['Name'].replace('', np.nan, inplace=True)
df = df.dropna()

# %%
dt['Price'] = dt['Price'].apply(pd.to_numeric)

# %%
df.head()
# Out:
#   Actionkey countryShort        Brand                    Name Price ProductId
# 2  purchase           SA       جيرلان     مون جيرلان - 100 مل   374      5220
# 3  purchase           SA      مانسيرا              ريد توباكو   441      6172
# 4  purchase           SA  كالفن كلاين  اتيرنتي مومنت - 100 مل   111      1817
# 5  purchase           SA     هو أمآي          جست يس - 100 مل   111     27940
# 6  purchase           SA   اليسا اشلي               امبر جريس   111      7133

# %%
#df.pivot_table(index =['Brand','Name'],  values ='Price')
df.groupby(['Brand','Name'])['Price'].sum()
# Out:
# Brand               Name
#  صوفيا فيرغارا      صوفيا فيرغارا صوفيا - 100 مل                                                                                    196
#  عطور هاوس أوف دان  روبي - 50 مل                                                                                                    294
#                     كاشمير سافرون معطر للشعر - 50 مل                                                                          105105105
#  فوريو              فوريو إيسبادا جهاز لعلاج حبوب البشرة - بينك                                                                     728
#                     فوريو لونا ميني 2  فرشاة لتنظيف الوجه - أكوامارين                                                               559
#                     فوريو لونا ميني 2  فرشاة لتنظيف الوجه - سن فلاور يالو                                                           559
# Alexandre.J         The Collector Black Muscs                                                                                       462
# Alyssa Ashley       Musk Extreme                                                                                                 111111
# BYS                 Eyeliner Liquid - 01 Black                                                                                       20
# Benefit             Benetint Cheek & Lip Stain                                                                                       96
# Burberry            Body Tender - 85 ml                                                                                             224
#                     My Burberry - 50 ml                                                                                             250
#                     My Burberry Black - 90 ml                                                                                    258258
# Bvlgari             Man In Black - 100 ml                                                                                           229
#                     Petits Et Mamans                                                                                                230
#                     Pour Femme - 100 ml                                                                                             336
# Cacharel            Noa - 100 ml                                                                                                     24
# Calvin Klein        Ck Beauty - 100 ml                                                                            111111111111111111111
#                     Escape - 100 ml                                                                                                 111
#                     Eternity Moment - 100 ml                                                                                  111111111
#                     Euphoria - 100 ml                                                                                            111111
#                     Euphoria Intense - 100 ml                                                                                23.2289289
#                     One Shock - 200 ml                                                                                           206111
# Cartier             Pasha Noire - 100 ml                                                                                            227
# Davidoff            The Game - 100 ml                                                                                               111
# Deem Perfumes       Baby Powder - 30 ml                                                                                              65
